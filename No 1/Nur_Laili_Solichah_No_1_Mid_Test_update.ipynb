# %% [markdown]
# # Business Understanding
# The task is to predict the survival on the Titanic based on the dataset of the onboard passengers of the historical journey embarked on April 15, 1912. The features include Gender, Age, Passenger class, Ticket Fare, Port of Embarkation, Family, etc. It requires a binary classification of 1/0, 1 meaning Survived and 0 meaning not survived. The input dataset has been split into training and testing sets which are available to the public through Kaggle. The output requirement is a CSV file with 2 columns - PassengerID and Survival prediction (1/0).

# %% [markdown]
# # Data Understanding
# The Dataset provides the annual water usage in Baltimore from 1885 to 1963, or 79 years of data.
# The values are in the units of liters per capita per day, and there are 79 observations. <br>
# **Download the dataset here**
# https://drive.google.com/open?id=1axM3gfGxQq4T0wuwP51DVMQAecVFmpxL
# <br>
# **Then answer the question**
# 1. Load the dataset as a Pandas Series and split into two, one for model development (dataset.csv) and the other for validation (validation.csv).
# 2. Create summary of the dataset, with python function.
# 3. Create A line plot of a time series dataset, it will provide a lot of insight into the problem.
# 4. Group the annual data by decade and get an idea of the spread of observations for each decade and how this may be changing.
# 5. Create models using ARIMA
#     - Split the dataset into train and test sets directly
#     The first 50% of the dataset will be held back to train the model.
#     - The remaining 50% of the dataset will be iterated and test the model.
#     - The ARIMA(p,d,q) model requires three parameters and is traditionally configured manually.
#     - Use an ARIMA(0,1,0) on the raw data may be a good starting point.
#     - When model trained, a one-step prediction made ang the prediction stored for later evaluation.
#     - The actual observation from the test dataset woll be added to the training dataset for the next iteration.
#     - The predictions made during the enumeration of the test dataset will be evaluated and an RMSE score reported.
# 6. Calculate the RMSE using the helper function from the scikit-learn library, from dataset only
#     - Those RMSE will show you on average, how much the error/the model was wrong/gap between predection and expected value per capita per day for each prediction made.

# %% [markdown]
# #### *1. Load the dataset as a Pandas Series and split into two, one for model development (dataset.csv) and the other for validation (validation.csv).*

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# import labelencoder
from sklearn.preprocessing import LabelEncoder

import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split

#import pacf/acf
from statsmodels.tsa.stattools import acf,pacf
from statsmodels.tsa.stattools import adfuller

#import arima
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error,mean_absolute_error

#import RSME
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
df =  pd.read_csv('water.csv', error_bad_lines=False)
df.head()
# Out:
# b'Skipping line 82: expected 2 fields, saw 3\n'
#    Year  Baltmore city annual water use, liters per capita per day, 1885-1968
# 0  1885                                                356
# 1  1886                                                386
# 2  1887                                                397
# 3  1888                                                397
# 4  1889                                                413

# %%
df.shape
# Out:
# (79, 2)

# %% [markdown]
# We know that this dataset (Annual Water Usage in Baltimore) contain 79 rows and 2 column

# %%
# rename colums Baltmore city annual water use, liters per capita per day, 1885-1968 as Year
df = df.rename(columns={'Baltmore city annual water use, liters per capita per day, 1885-1968': 'water'})
df.water = df.water.astype('float64')

# %%
# set year as a index used to analyzed in time series analysis
df = df.set_index('Year')
df.head()
# Out:
#       water
# Year
# 1885  356.0
# 1886  386.0
# 1887  397.0
# 1888  397.0
# 1889  413.0

# %%
# state dataset 69 row 
split_point = len(df) - 10
dataset, validation = df[0:split_point], df[split_point:]
print('Dataset %d, Validation %d' % (len(dataset), len(validation)))
dataset.to_csv('dataset.csv', index=False)
validation.to_csv('validation.csv', index=False)
# Out:
# Dataset 69, Validation 10

# %% [markdown]
# #### *2. Create summary of the dataset, with python function.*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79 entries, 1885 to 1963
# Data columns (total 1 columns):
# water    79 non-null float64
# dtypes: float64(1)
# memory usage: 1.2 KB

# %% [markdown]
# all the types of data is float64

# %%
df.describe()
# Out:
#             water
# count   79.000000
# mean   512.025316
# std     75.685072
# min    344.000000
# 25%    462.000000
# 50%    503.000000
# 75%    581.000000
# max    662.000000

# %%
X_train, X_validation = train_test_split(df, test_size=0.33, shuffle=False)
len(X_train), len(X_validation)
# Out:
# (52, 27)

# %% [markdown]
# #### *3. Create A line plot of a time series dataset, it will provide a lot of insight into the problem.*

# %%
# create line plot from dataset.csv or train data
X_train.plot(figsize=(8,8))
plt.xlabel('Year')
plt.ylabel('Annual Water Usage')
plt.title('Annual Water Usage in Baltimore')
plt.show()

# %% [markdown]
# Based on the **line plot**, we can know that:
# 1. Annual water usage in Baltimore is fluctuative and the trend tends to increase
# 2. At some moment the water usage is dropped dramatically, and
# 3. At some moment the water usage is rose dramatically. <br>
#
# Then can do **Rolling Statistics**. Because, it can be seen that the plot of rolling mean and rolling std is in a straight line (it does not have a specific pattern or pattern). So it can be said that the feature water use is stationary in the range/variance and mean/mean of the annual water usage.

# %%
rolmean = X_train.rolling(window=2).mean()
rolstd = X_train.rolling(window=2).std()
plt.plot(X_train)
plt.plot(rolmean,color='red',label='Roling Mean')
plt.plot(rolstd,color='black',label='Roling STD')
plt.xlabel('Year')
plt.ylabel('Annual Water Usage')
plt.title('The Rolling Mean and Standard Deviation Annual Water Usage in Baltimore')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# Based on the visualization, we can know the calculate of rolling mean and standard deviation on annual water usage in a year. There is no significance difference between the result of rolling mean and rolling standard deviation.

# %%
# subplot graph
X_train.plot(kind='kde')

# %% [markdown]
# Based on the subplot, the distribution is not Gaussian, but close to.

# %% [markdown]
# #### *4. Group the annual data by decade and get an idea of the spread of observations for each decade and how this may be changing.*

# %%
# check min and max year
dfdecade =  pd.read_csv('water.csv', error_bad_lines=False)
dfdecade = dfdecade.rename(columns={'Baltmore city annual water use, liters per capita per day, 1885-1968': 'water'})
dfdecade.water = dfdecade.water.astype('float64')
dfdecade['Year'].min()
# Out:
# b'Skipping line 82: expected 2 fields, saw 3\n'
# 1885

# %%
dfdecade['Year'].max()
# Out:
# 1963

# %%
labels=["{0} - {1}".format(i, i+9) for i in range(1885, 1960, 10)]
dfdecade['Decade']=pd.cut(dfdecade.Year, range(1885, 1968, 10), right=False, labels=labels)

# %%
dfdecade.head()
# Out:
#    Year  water       Decade
# 0  1885  356.0  1885 - 1894
# 1  1886  386.0  1885 - 1894
# 2  1887  397.0  1885 - 1894
# 3  1888  397.0  1885 - 1894
# 4  1889  413.0  1885 - 1894

# %% [markdown]
# #### *5. Create models using ARIMA*

# %% [markdown]
# **Auto-Regressive Integrated Moving Average (ARIMA)**: The ARIMA forecasting for a stationary time series is a linear funcion similar to linear regression. The predictors mainly depend on the parameters (p,d,q) of the ARIMA mode.

# %% [markdown]
# ####  5.1 Plot the ACF and PACF charts and find the optimal parameters
# - **Autocorrelation Function (ACF)**: It is a measure of the correlation between the the time series (ts) with a lagged version of itself. For instance at lag 4, ACF would compare series at time instant ‘t1’…’t2’ with series at instant ‘t1-4’…’t2-4’ (t1-4 and t2 being end points of the range).
# - **Partial Autocorrelation Function (PACF)**: This measures the correlation between the ts with a lagged version of itself but after eliminating the variations already explained by the intervening comparisons. Eg at lag 4, it will check the correlation but remove the effects already explained by lags 1 to 3.

# %%
#TestStationaryAdfuller
print('Dickey-fuller test')
dftest = adfuller(X_train['water'],autolag='AIC')
print(dftest)
dfoutput=pd.Series(dftest[0:4],index=['Test Stat','p-value','lag_used','number of obs used'])
dfoutput
# Out:
# Dickey-fuller test
# (-2.7421004965362523, 0.06703204860767971, 1, 50, {'1%': -3.568485864, '5%': -2.92135992, '10%': -2.5986616}, 384.2395531843111)
# Test Stat             -2.742100
# p-value                0.067032
# lag_used               1.000000
# number of obs used    50.000000
# dtype: float64

# %% [markdown]
# **The Dickey–Fuller test** tests the null hypothesis that a unit root is present in an autoregressive model. The alternative hypothesis is different depending on which version of the test is used, but is usually stationarity or trend-stationarity.

# %%
X_train2 = np.log(X_train)
rolmean = X_train2.rolling(window=2).mean()
rolstd = X_train2.rolling(window=2).std()
plt.plot(X_train2)
plt.plot(rolmean,color='red',label='Roling Mean')
plt.plot(rolstd,color='black',label='Roling STD')
plt.xlabel('Year')
plt.ylabel('Annual Water Usage')
plt.title('The Rolling Mean and Standard Deviation Annual Water Usage in Baltimore')
plt.legend(loc='best')
plt.show()

# %%
plt.plot(rolstd,color='blue',label='Rolling Standard Deviation')

# %%
diff = X_train['water'] - X_train['water'].shift()
diff = diff.dropna()

rolmean = diff.rolling(window=2).mean()
rolstd = diff.rolling(window=2).std()
plt.plot(diff)
plt.plot(rolmean,color='red',label='Roling Mean')
plt.plot(rolstd,color='black',label='Roling STD')
plt.legend(loc='best')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.plot(diff)

# %%
print('Dickey-fuller test')

dftest = adfuller(diff,autolag='AIC')
print(dftest)
dfoutput = pd.Series(dftest[0:4],index=['Test Stat','p-value','lag_used','number of obs used'])
dfoutput
# Out:
# Dickey-fuller test
# (-5.27370010615997, 6.20599989595577e-06, 1, 49, {'1%': -3.5714715250448363, '5%': -2.922629480573571, '10%': -2.5993358475635153}, 381.5868098955805)
# Test Stat             -5.273700
# p-value                0.000006
# lag_used               1.000000
# number of obs used    49.000000
# dtype: float64

# %% [markdown]
# The results of the p-value show that **H0 is rejected**, it is stationary between variance and average. Value of d = 0 **Just looking for AR and MA (p and q)**

# %% [markdown]
# #### GRAPH OF PACF/ACF

# %%
import statsmodels.graphics.tsaplots as sts
sts.plot_acf(X_train, lags=20)
sts.plot_pacf(X_train, lags=20)
plt.show()

# %% [markdown]
# Determination of ACF values based on cut-off values from the plot results. ACF plot results using lags of 10, note that the value of **ACF = 3**. This value is a value that represents the amount of the Autoregressive Integrated (AR) value
#
# Determination of PACF values based on cut-off values from the plot results. PACF plot results using lags of 30, note that the value of **PACF = 2**. This value is a value that represents the value of the Moving Average (MA)

# %%
model = ARIMA(X_train, order=(1,0,2))
results = model.fit()
model_val = ARIMA(X_validation, order=(1,0,2))
results_val = model_val.fit()
predictions = results.fittedvalues
predictions_val = results_val.fittedvalues
plt.plot(X_train)
plt.plot(predictions, color='red')
plt.title('RSS: %.4F' % sum((results.fittedvalues-df['water'])**2))
print('Plotting ARIMA model')
# Out:
# Plotting ARIMA model

# %%
results.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                           Results: ARMA
# ==================================================================
# Model:              ARMA             BIC:                 540.0820
# Dependent Variable: water            Log-Likelihood:      -260.16
# Date:               2019-10-10 18:17 Scale:               1.0000
# No. Observations:   52               Method:              css-mle
# Df Model:           4                Sample:              0
# Df Residuals:       48                                    2
# Converged:          1.0000           S.D. of innovations: 35.619
# No. Iterations:     21.0000          HQIC:                534.066
# AIC:                530.3258
# ------------------------------------------------------------------
#                  Coef.   Std.Err.    t    P>|t|   [0.025   0.975]
# ------------------------------------------------------------------
# const           469.7438  19.1653 24.5101 0.0000 432.1804 507.3071
# ar.L1.water       0.6052   0.2371  2.5527 0.0139   0.1405   1.0699
# ma.L1.water       0.3533   0.2863  1.2340 0.2232  -0.2078   0.9144
# ma.L2.water       0.2330   0.2405  0.9690 0.3374  -0.2383   0.7044
# --------------------------------------------------------------------------
#                  Real          Imaginary         Modulus         Frequency
# --------------------------------------------------------------------------
# AR.1            1.6524            0.0000          1.6524            0.0000
# MA.1           -0.7579           -1.9278          2.0715           -0.3096
# MA.2           -0.7579            1.9278          2.0715            0.3096
# ==================================================================
#
# """

# %%
results.plot_predict(1,70)

# %% [markdown]
# #### *6. Calculate the RMSE using the helper function from the scikit-learn library, from dataset only*

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

MAPE = mean_absolute_percentage_error(X_train, pd.DataFrame(predictions).round(0))
print('Value of MAPE from ARIMA : %.2f%%' % (MAPE))
# Out:
# Value of MAPE from ARIMA : 5.25%

# %%
MSE = mean_squared_error(X_train, predictions)
RMSE = sqrt(MSE)
print('Value RMSE from ARIMA : %.2f' % (RMSE))
# Out:
# Value RMSE from ARIMA : 37.86

# %% [markdown]
# **This is the purpose from data validation**

# %%
x = results.forecast(steps=52+27)

# %%
MAPE = mean_absolute_percentage_error(X_validation, pd.DataFrame(x[0][52:]).round(0))
print('MAPE value from ARIMA with data validation as a comparison: %.2f%%' % (MAPE))
# Out:
# MAPE value from ARIMA with data validation as a comparison: 19.69%

# %%
MSE = mean_squared_error(X_validation, x[0][52:])
RMSE = sqrt(MSE)
print('The RMSE value of the ARIMA model with data validation as a comparison: %.2f' % (RMSE))
# Out:
# The RMSE value of the ARIMA model with data validation as a comparison: 121.82

# %% [markdown]
# ## Additional Visualization (*Actual and Prediction Annual Water Usage in Baltimore*)

# %%
#new dataframe prediction
predict = pd.DataFrame(results.fittedvalues, copy=True)
predict['Predict Water Usage'] = predict
predict = predict.drop([0],1)
predict.head()
# Out:
#       Predict Water Usage
# Year
# 1885           469.743761
# 1886           378.762139
# 1887           412.760130
# 1888           421.876623
# 1889           413.337472

# %%
#merge data training actual and data prediction
dftrain = X_train.merge(predict, left_index=True, right_index=True)
print(dftrain.shape)
dftrain.tail()
# Out:
# (52, 2)
#       water  Predict Water Usage
# Year
# 1932  488.0           501.567061
# 1933  466.0           484.557663
# 1934  492.0           457.760412
# 1935  503.0           490.984204
# 1936  515.0           502.094639

# %% [markdown]
# columns water is a value of actual water usage.

# %%
#Actual and Predict in data training in ARIMA
plt.figure(figsize=(8,6))
plt.plot(dftrain['water'], color='blue', label='Actual')
plt.plot(dftrain['Predict Water Usage'], color='red', label='Predict')
plt.legend()
plt.show()

# %% [markdown]
# We can conclude that the result between **actual and predicted are not too different**.

# %%
predict = pd.DataFrame(results_val.fittedvalues, copy=True)
predict['Predict Water Usage'] = predict
predict = predict.drop([0],1)
predict.head()
dftest = X_validation.merge(predict, left_index=True, right_index=True)
print(dftest.shape)
dftest.head()
# Out:
# (27, 2)
#       water  Predict Water Usage
# Year
# 1937  500.0           585.184857
# 1938  522.0           530.423504
# 1939  575.0           566.430510
# 1940  583.0           595.375056
# 1941  587.0           572.857367

# %% [markdown]
# ## Conclusion
# This dataset using ARIMA to analyze the time series for Annual Water Usage in Baltimore. This dataset split the Year for two data, as follows:
# 1. Dataset.csv which is training data start from 1936 until 1985 -> 70%
# 2. Validation.csv which is testing data start from 1937 until 1963<br> -> 30%
#
# The results of the p-value show that **H0 is rejected**, it is stationary between variance and average. Value of d = 0 **Just looking for AR and MA (p and q)**.<br>
